# %%
import os

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import torch
import json
from omegaconf.omegaconf import OmegaConf, open_dict
import shutil

from nemo.collections.tts.models.speechllm.megatron_t5_speechllm_model import MegatronT5SpeechLMModel
from nemo.collections.nlp.parts.megatron_trainer_builder import MegatronTrainerBuilder
from nemo.collections.asr.parts.preprocessing.segment import AudioSegment
from nemo.core.config import hydra_runner
from nemo.utils import logging
from nemo.utils.exp_manager import exp_manager
from IPython.display import Audio, display
import torchaudio

# CHANGE THIS TO A LOCAL DIRECTORY
EXP_DIR = "/Data/NotebookInference"

if not os.path.exists(EXP_DIR):
    os.makedirs(EXP_DIR)

# %% [markdown]
# ## Save a dummy manifest to setup Model Test Step

# %%
def write_records(fp, records):
    with open(fp, "w") as f:
        for record in records:
            f.write(json.dumps(record) + "\n")

dummy_codes = torch.ones(8, 300).cpu().type(torch.int16)
dummy_codes_fp = os.path.join(EXP_DIR, "dummy_codes.pt")
torch.save(dummy_codes, dummy_codes_fp)


dummy_record = {
    "question" : "Phoneme TTS Sample Text",
    "answer" : dummy_codes_fp,
    "context" : dummy_codes_fp,
    "context_type" : "REFSPEAKERCODEC",
    "question_type" : "TEXT",
    "answer_type" : "AUDIOCODEC",
    "context_duration" : 5.0,
    "answer_duration" : 5.0,
    "taskname" : "squad"
}

dummy_val_file = os.path.join(EXP_DIR, "dummy_val.json")

write_records(dummy_val_file, [dummy_record])

# %% [markdown]
# ## Load and setup the model

# %%
# CHANGE THESE PATHS TO RELEVANT MOUNTED PATHS IN DOCKER
config_path = "/home/shehzeenh/Code/NeMo/examples/tts/speechllm/conf/megatron_t5_speechllm_inference_multiencoder.yaml"
# checkpoint_path = "/datap/misc/temp_checkpoints_new/desta_less_sophia_highLR_step159600.ckpt"
# checkpoint_path = "/Data/Checkpoints/multiencoder21Hz2k_nodesta_onlyIPA_step298k.ckpt"
checkpoint_path = "/Data/21_hz_release_candidates/no_yt/megatron_t5_speechllm_tts--val_loss=41.662-step=162478.ckpt"
# codecmodel_path = "/Data/Checkpoints/AudioCodec_21Hz-2k-codes_updated.nemo"
codecmodel_path = "/Data/Checkpoints/AudioCodec_21Hz_no_eliz.nemo"
vocab_file = "/Data/Checkpoints/9a77f10c2793465e8e8a3fa5fcbef8b0_vocab.txt"

cfg = OmegaConf.load(config_path)

if "gradient_as_bucket_view" not in cfg.model:
    with open_dict(cfg):
        cfg.model.gradient_as_bucket_view=False

trainer = MegatronTrainerBuilder(cfg).create_trainer()
exp_manager(trainer, cfg.exp_manager)

with open_dict(cfg):
    cfg.exp_manager.exp_dir=EXP_DIR
    cfg.checkpoint_path = checkpoint_path
    cfg.model.data.sup_data_path="/datap/misc/speechllm_codecdatasets/"
    cfg.model.global_batch_size=1
    cfg.model.micro_batch_size=1
    cfg.model.lm_vocab_size=30000
    cfg.model.data.add_special_tokens_to_only_first_codebook=True
    cfg.model.data.train_task="all"
    cfg.model.freeze_model=False
    cfg.model.data.max_seq_length=512
    cfg.model.max_inference_timesteps=510
    cfg.model.data.context_duration_min=20.0
    cfg.model.data.context_duration_max=20.0
    cfg.model.top_k=80
    cfg.model.temperature=0.85
    cfg.model.data.speech_offset=30128
    cfg.model.data.speech_codebook_size=2048
    cfg.model.codecmodel_path=codecmodel_path
    cfg.trainer.devices=1
    cfg.trainer.precision="bf16"
    cfg.model.precision = cfg.trainer.precision
    cfg.model.override_tokenizer_vocab_file=vocab_file
    cfg.model.english_only_model=True
    cfg.model.asr_model_name="stt_en_conformer_transducer_large"
    cfg.model.frozen_model.decoder.layer_type=[1,1,1,2,2,2,2,2,2,2,1,1]
    cfg.model.alignment_decoder_layerids=[0,1,2,3,4]
    cfg.model.enc_output_to_layers=[[8,9],[3,4,5,6,7]]
    cfg.model.data.test_ds=[dummy_val_file]
    cfg.model.data.num_workers = 0
    cfg.model.data.use_ipa=True
    cfg.model.data.codebook_fps=21


checkpoint_path = cfg.get('checkpoint_path', None)
assert checkpoint_path is not None, "checkpoint path needs to be valid"

model = MegatronT5SpeechLMModel.load_from_checkpoint(
        checkpoint_path=checkpoint_path, trainer=trainer, cfg=cfg.model
    )
model.eval()
model = model.cuda()

codec_model = model.additional_models['codec']
trainer.test(model)
# Out:
# [NeMo I 2024-10-25 06:48:34 megatron_trainer_builder:51] Detected interactive environment, using NLPDDPStrategyNotebook
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [NeMo W 2024-10-25 06:48:34 exp_manager:780] No version folders would be created under the log folder as 'resume_if_exists' is enabled.
# [NeMo W 2024-10-25 06:48:34 exp_manager:636] There were no checkpoints found in checkpoint_dir or no checkpoint folder at checkpoint_dir :/home/shehzeenh/Code/NeMo/nemo_experiments/megatron_t5_speechllm/checkpoints. Training from scratch.
# [NeMo I 2024-10-25 06:48:34 exp_manager:402] Experiments will be logged at /home/shehzeenh/Code/NeMo/nemo_experiments/megatron_t5_speechllm
# [NeMo I 2024-10-25 06:48:34 exp_manager:863] TensorboardLogger has been set up
# [NeMo W 2024-10-25 06:48:34 exp_manager:973] The checkpoint callback was told to monitor a validation value and trainer's max_steps was set to 250000. Please ensure that max_steps will run for at least 1 epochs to ensure that checkpointing will not error out.
# [NeMo W 2024-10-25 06:48:34 nemo_model_checkpoint:58] Found save_best_model is True and save_nemo_on_train_end is False. Set save_nemo_on_train_end to True to automatically save the best model.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: context_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: virtual_pipeline_model_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: sequence_parallel in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: expert_model_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: use_cpu_initialization in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: gradient_accumulation_fusion in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: tp_comm_overlap in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: tp_comm_split_ag in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: tp_comm_split_rs in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: tp_comm_bulk_wgrad in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: tp_comm_bulk_dgrad in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: finalize_model_grads_func in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: overlap_p2p_comm in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: batch_p2p_comm in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: pipeline_model_parallel_split_rank in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: barrier_with_L1_time in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1089] hidden_size not found in {'seed': 1234, 'nemo_path': 'megatron_t5_speechllm.nemo', 'virtual_prompt_style': 'p-tuning', 'tensor_model_parallel_size': 1, 'pipeline_model_parallel_size': 1, 'global_batch_size': 1, 'micro_batch_size': 1, 'validation_global_batch_size': 1, 'validation_micro_batch_size': 1, 'validation_drop_last': False, 'report_validation_metric': False, 'validation_metric': 'accuracy', 'num_speech_tokens': 10112, 'seq_pattern': 'parallel', 'temperature': 0.85, 'top_k': 80, 'max_inference_timesteps': 510, 'restore_path': None, 'save_nemo_on_validation_end': True, 'existing_tasks': [], 'new_tasks': ['squad'], 'codecmodel_type': 'nemo_codec', 'codecmodel_path': '/Data/Checkpoints/AudioCodec_21Hz_no_eliz.nemo', 'english_only_model': True, 'context_conditioning': 'encoder', 'train_from_scratch': True, 'override_tokenizer_vocab_file': '/Data/Checkpoints/9a77f10c2793465e8e8a3fa5fcbef8b0_vocab.txt', 'use_flash_attention': False, 'lm_vocab_size': 30000, 'enc_output_to_layers': [[8, 9], [3, 4, 5, 6, 7]], 'frozen_model': {'tensor_model_parallel_size': 1, 'pipeline_model_parallel_size': 1, 'pipeline_model_parallel_split_rank': 0, 'make_vocab_size_divisible_by': 128, 'pre_process': True, 'post_process': True, 'gradient_as_bucket_view': True, 'native_amp_init_scale': 4294967296, 'native_amp_growth_interval': 1000, 'fp16_lm_cross_entropy': False, 'seed': 1234, 'use_cpu_initialization': False, 'apex_transformer_log_level': 30, 'tokenizer': {'library': 'megatron', 'type': 'BertWordPieceCase', 'model': None, 'vocab_file': None, 'merge_file': None}, 'optim': {'name': None}, 'data': {'dataset_type': 't5'}, 'encoder': {'arch': 'multi_transformer', 'n_transformers': 2, 'bias_activation_fusion': False, 'use_flash_attention': False, 'num_layers': 6, 'hidden_size': 768, 'ffn_hidden_size': 2048, 'num_attention_heads': 12, 'init_method_std': 0.015, 'hidden_dropout': 0.1, 'attention_dropout': 0.1, 'kv_channels': 64, 'activation': 'geglu'}, 'decoder': {'arch': 'transformer', 'bias_activation_fusion': False, 'use_flash_attention': False, 'num_layers': 12, 'hidden_size': 768, 'ffn_hidden_size': 2048, 'num_attention_heads': 12, 'init_method_std': 0.015, 'hidden_dropout': 0.1, 'attention_dropout': 0.1, 'kv_channels': 64, 'activation': 'geglu', 'layer_type': [1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 1, 1]}}, 'task_templates': [{'taskname': 'squad', 'prompt_template': '<|VIRTUAL_PROMPT_0|> {context} {question} {answer}', 'total_virtual_tokens': 3, 'virtual_token_splits': [3], 'truncate_field': 'context', 'answer_field': 'answer'}], 'p_tuning': {'encoder_type': 'mlp', 'num_layers': 2, 'dropout': 0.0}, 'prompt_tuning': {'new_prompt_init_methods': ['text'], 'new_prompt_init_text': ['some init text goes here']}, 'data': {'grapheme_prefix': None, 'train_ds': None, 'validation_ds': None, 'test_ds': ['/Data/NotebookInference/dummy_val.json'], 'max_seq_length': 512, 'sample_rate': 24000, 'add_eos': True, 'add_bos': False, 'use_attention_prior': False, 'attention_prior_scaling_factor': 0.05, 'cross_attention_epsilon': 0.0, 'decoder_starts_with_pad': False, 'add_eos_to_decoder_output': True, 'add_sentinel_to_input': True, 'ul2_prompt_token': None, 'shuffle': True, 'num_workers': 0, 'pin_memory': True, 'speech_offset': 30128, 'train_task': 'all', 'sup_data_path': '/datap/misc/speechllm_codecdatasets/', 'num_speech_codebooks': 8, 'codebook_fps': 21, 'context_duration_min': 20.0, 'context_duration_max': 20.0, 'context_slice_method': 'fixed', 'phoneme_probability': 1.0, 'encoder_type': 'multi_transformer', 'g2p': {'english': {'_target_': 'nemo.collections.tts.g2p.models.i18n_ipa.IpaG2p', 'phoneme_dict': 'scripts/tts_dataset_files/ipa_cmudict-0.7b_nv23.01.txt', 'heteronyms': 'scripts/tts_dataset_files/heteronyms-052722', 'phoneme_probability': 0.8, 'ignore_ambiguous_words': False, 'use_chars': True, 'use_stresses': True, 'grapheme_prefix': None}, 'spanish': {'_target_': 'nemo.collections.tts.g2p.models.i18n_ipa.IpaG2p',  ...
# [NeMo I 2024-10-25 06:48:36 megatron_init:241] Rank 0 has data parallel group : [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:247] Rank 0 has combined group of data parallel and context parallel : [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:252] All data parallel group ranks with context parallel combined: [[0]]
# [NeMo I 2024-10-25 06:48:36 megatron_init:255] Ranks 0 has data parallel rank: 0
# [NeMo I 2024-10-25 06:48:36 megatron_init:272] Rank 0 has context parallel group: [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:275] All context parallel group ranks: [[0]]
# [NeMo I 2024-10-25 06:48:36 megatron_init:276] Ranks 0 has context parallel rank: 0
# [NeMo I 2024-10-25 06:48:36 megatron_init:287] Rank 0 has model parallel group: [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:288] All model parallel group ranks: [[0]]
# [NeMo I 2024-10-25 06:48:36 megatron_init:298] Rank 0 has tensor model parallel group: [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:302] All tensor model parallel group ranks: [[0]]
# [NeMo I 2024-10-25 06:48:36 megatron_init:303] Rank 0 has tensor model parallel rank: 0
# [NeMo I 2024-10-25 06:48:36 megatron_init:317] Rank 0 has pipeline model parallel group: [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:329] Rank 0 has embedding group: [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:335] All pipeline model parallel group ranks: [[0]]
# [NeMo I 2024-10-25 06:48:36 megatron_init:336] Rank 0 has pipeline model parallel rank 0
# [NeMo I 2024-10-25 06:48:36 megatron_init:337] All embedding group ranks: [[0]]
# [NeMo I 2024-10-25 06:48:36 megatron_init:338] Rank 0 has embedding rank: 0
# [W init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: context_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: virtual_pipeline_model_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: sequence_parallel in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: expert_model_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: use_cpu_initialization in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: gradient_accumulation_fusion in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: tp_comm_overlap in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: tp_comm_split_ag in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: tp_comm_split_rs in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: tp_comm_bulk_wgrad in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: tp_comm_bulk_dgrad in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: finalize_model_grads_func in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: overlap_p2p_comm in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: batch_p2p_comm in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: pipeline_model_parallel_split_rank in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5SpeechLMModel() does not have field.name: barrier_with_L1_time in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1089] hidden_size not found in {'seed': 1234, 'nemo_path': 'megatron_t5_speechllm.nemo', 'virtual_prompt_style': 'p-tuning', 'tensor_model_parallel_size': 1, 'pipeline_model_parallel_size': 1, 'global_batch_size': 1, 'micro_batch_size': 1, 'validation_global_batch_size': 1, 'validation_micro_batch_size': 1, 'validation_drop_last': False, 'report_validation_metric': False, 'validation_metric': 'accuracy', 'num_speech_tokens': 10112, 'seq_pattern': 'parallel', 'temperature': 0.85, 'top_k': 80, 'max_inference_timesteps': 510, 'restore_path': None, 'save_nemo_on_validation_end': True, 'existing_tasks': [], 'new_tasks': ['squad'], 'codecmodel_type': 'nemo_codec', 'codecmodel_path': '/Data/Checkpoints/AudioCodec_21Hz_no_eliz.nemo', 'english_only_model': True, 'context_conditioning': 'encoder', 'train_from_scratch': True, 'override_tokenizer_vocab_file': '/Data/Checkpoints/9a77f10c2793465e8e8a3fa5fcbef8b0_vocab.txt', 'use_flash_attention': False, 'lm_vocab_size': 30000, 'enc_output_to_layers': [[8, 9], [3, 4, 5, 6, 7]], 'frozen_model': {'tensor_model_parallel_size': 1, 'pipeline_model_parallel_size': 1, 'pipeline_model_parallel_split_rank': 0, 'make_vocab_size_divisible_by': 128, 'pre_process': True, 'post_process': True, 'gradient_as_bucket_view': True, 'native_amp_init_scale': 4294967296, 'native_amp_growth_interval': 1000, 'fp16_lm_cross_entropy': False, 'seed': 1234, 'use_cpu_initialization': False, 'apex_transformer_log_level': 30, 'tokenizer': {'library': 'megatron', 'type': 'BertWordPieceCase', 'model': None, 'vocab_file': None, 'merge_file': None}, 'optim': {'name': None}, 'data': {'dataset_type': 't5'}, 'encoder': {'arch': 'multi_transformer', 'n_transformers': 2, 'bias_activation_fusion': False, 'use_flash_attention': False, 'num_layers': 6, 'hidden_size': 768, 'ffn_hidden_size': 2048, 'num_attention_heads': 12, 'init_method_std': 0.015, 'hidden_dropout': 0.1, 'attention_dropout': 0.1, 'kv_channels': 64, 'activation': 'geglu'}, 'decoder': {'arch': 'transformer', 'bias_activation_fusion': False, 'use_flash_attention': False, 'num_layers': 12, 'hidden_size': 768, 'ffn_hidden_size': 2048, 'num_attention_heads': 12, 'init_method_std': 0.015, 'hidden_dropout': 0.1, 'attention_dropout': 0.1, 'kv_channels': 64, 'activation': 'geglu', 'layer_type': [1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 1, 1]}}, 'task_templates': [{'taskname': 'squad', 'prompt_template': '<|VIRTUAL_PROMPT_0|> {context} {question} {answer}', 'total_virtual_tokens': 3, 'virtual_token_splits': [3], 'truncate_field': 'context', 'answer_field': 'answer'}], 'p_tuning': {'encoder_type': 'mlp', 'num_layers': 2, 'dropout': 0.0}, 'prompt_tuning': {'new_prompt_init_methods': ['text'], 'new_prompt_init_text': ['some init text goes here']}, 'data': {'grapheme_prefix': None, 'train_ds': None, 'validation_ds': None, 'test_ds': ['/Data/NotebookInference/dummy_val.json'], 'max_seq_length': 512, 'sample_rate': 24000, 'add_eos': True, 'add_bos': False, 'use_attention_prior': False, 'attention_prior_scaling_factor': 0.05, 'cross_attention_epsilon': 0.0, 'decoder_starts_with_pad': False, 'add_eos_to_decoder_output': True, 'add_sentinel_to_input': True, 'ul2_prompt_token': None, 'shuffle': True, 'num_workers': 0, 'pin_memory': True, 'speech_offset': 30128, 'train_task': 'all', 'sup_data_path': '/datap/misc/speechllm_codecdatasets/', 'num_speech_codebooks': 8, 'codebook_fps': 21, 'context_duration_min': 20.0, 'context_duration_max': 20.0, 'context_slice_method': 'fixed', 'phoneme_probability': 1.0, 'encoder_type': 'multi_transformer', 'g2p': {'english': {'_target_': 'nemo.collections.tts.g2p.models.i18n_ipa.IpaG2p', 'phoneme_dict': 'scripts/tts_dataset_files/ipa_cmudict-0.7b_nv23.01.txt', 'heteronyms': 'scripts/tts_dataset_files/heteronyms-052722', 'phoneme_probability': 0.8, 'ignore_ambiguous_words': False, 'use_chars': True, 'use_stresses': True, 'grapheme_prefix': None}, 'spanish': {'_target_': 'nemo.collections.tts.g2p.models.i18n_ipa.IpaG2p',  ...
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: context_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: virtual_pipeline_model_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: sequence_parallel in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: expert_model_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: gradient_accumulation_fusion in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: tp_comm_overlap in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: tp_comm_split_ag in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: tp_comm_split_rs in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: tp_comm_bulk_wgrad in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: tp_comm_bulk_dgrad in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: finalize_model_grads_func in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: overlap_p2p_comm in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: batch_p2p_comm in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: barrier_with_L1_time in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1089] hidden_size not found in {'tensor_model_parallel_size': 1, 'pipeline_model_parallel_size': 1, 'pipeline_model_parallel_split_rank': 0, 'make_vocab_size_divisible_by': 128, 'pre_process': True, 'post_process': True, 'gradient_as_bucket_view': True, 'native_amp_init_scale': 4294967296, 'native_amp_growth_interval': 1000, 'fp16_lm_cross_entropy': False, 'seed': 1234, 'use_cpu_initialization': False, 'apex_transformer_log_level': 30, 'tokenizer': {'library': 'megatron', 'type': 'BertWordPieceCase', 'model': None, 'vocab_file': '/Data/Checkpoints/9a77f10c2793465e8e8a3fa5fcbef8b0_vocab.txt', 'merge_file': None, 'num_sentinel_tokens': 10128}, 'optim': {'name': None}, 'data': {'dataset_type': 't5'}, 'encoder': {'arch': 'multi_transformer', 'n_transformers': 2, 'bias_activation_fusion': False, 'use_flash_attention': False, 'num_layers': 6, 'hidden_size': 768, 'ffn_hidden_size': 2048, 'num_attention_heads': 12, 'init_method_std': 0.015, 'hidden_dropout': 0.1, 'attention_dropout': 0.1, 'kv_channels': 64, 'activation': 'geglu', 'masked_softmax_fusion': False}, 'decoder': {'arch': 'transformer', 'bias_activation_fusion': False, 'use_flash_attention': False, 'num_layers': 12, 'hidden_size': 768, 'ffn_hidden_size': 2048, 'num_attention_heads': 12, 'init_method_std': 0.015, 'hidden_dropout': 0.1, 'attention_dropout': 0.1, 'kv_channels': 64, 'activation': 'geglu', 'layer_type': [1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 1, 1], 'masked_softmax_fusion': False}, 'megatron_amp_O2': False, 'micro_batch_size': 1, 'global_batch_size': 1, 'precision': '32-true', 'seq_length': 512, 'max_position_embeddings': 512, 'use_flash_attention': False, 'target': 'nemo.collections.tts.models.speechllm.megatron_t5_speechllm_model.MegatronT5OverrideModel', 'nemo_version': '1.23.0rc0'}. Set this in model_parallel_config if using pipeline parallelism.
# Training from scratch!
# [NeMo I 2024-10-25 06:48:36 megatron_init:241] Rank 0 has data parallel group : [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:247] Rank 0 has combined group of data parallel and context parallel : [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:252] All data parallel group ranks with context parallel combined: [[0]]
# [NeMo I 2024-10-25 06:48:36 megatron_init:255] Ranks 0 has data parallel rank: 0
# [NeMo I 2024-10-25 06:48:36 megatron_init:272] Rank 0 has context parallel group: [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:275] All context parallel group ranks: [[0]]
# [NeMo I 2024-10-25 06:48:36 megatron_init:276] Ranks 0 has context parallel rank: 0
# [NeMo I 2024-10-25 06:48:36 megatron_init:287] Rank 0 has model parallel group: [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:288] All model parallel group ranks: [[0]]
# [NeMo I 2024-10-25 06:48:36 megatron_init:298] Rank 0 has tensor model parallel group: [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:302] All tensor model parallel group ranks: [[0]]
# [NeMo I 2024-10-25 06:48:36 megatron_init:303] Rank 0 has tensor model parallel rank: 0
# [NeMo I 2024-10-25 06:48:36 megatron_init:317] Rank 0 has pipeline model parallel group: [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:329] Rank 0 has embedding group: [0]
# [NeMo I 2024-10-25 06:48:36 megatron_init:335] All pipeline model parallel group ranks: [[0]]
# [NeMo I 2024-10-25 06:48:36 megatron_init:336] Rank 0 has pipeline model parallel rank 0
# [NeMo I 2024-10-25 06:48:36 megatron_init:337] All embedding group ranks: [[0]]
# [NeMo I 2024-10-25 06:48:36 megatron_init:338] Rank 0 has embedding rank: 0
# [W init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: context_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: virtual_pipeline_model_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: sequence_parallel in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: expert_model_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: gradient_accumulation_fusion in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: tp_comm_overlap in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: tp_comm_split_ag in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: tp_comm_split_rs in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: tp_comm_bulk_wgrad in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: tp_comm_bulk_dgrad in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: finalize_model_grads_func in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: overlap_p2p_comm in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: batch_p2p_comm in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1078] The model: MegatronT5OverrideModel() does not have field.name: barrier_with_L1_time in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-10-25 06:48:36 megatron_base_model:1089] hidden_size not found in {'tensor_model_parallel_size': 1, 'pipeline_model_parallel_size': 1, 'pipeline_model_parallel_split_rank': 0, 'make_vocab_size_divisible_by': 128, 'pre_process': True, 'post_process': True, 'gradient_as_bucket_view': True, 'native_amp_init_scale': 4294967296, 'native_amp_growth_interval': 1000, 'fp16_lm_cross_entropy': False, 'seed': 1234, 'use_cpu_initialization': False, 'apex_transformer_log_level': 30, 'tokenizer': {'library': 'megatron', 'type': 'BertWordPieceCase', 'model': None, 'vocab_file': '/Data/Checkpoints/9a77f10c2793465e8e8a3fa5fcbef8b0_vocab.txt', 'merge_file': None, 'num_sentinel_tokens': 10128}, 'optim': {'name': None}, 'data': {'dataset_type': 't5'}, 'encoder': {'arch': 'multi_transformer', 'n_transformers': 2, 'bias_activation_fusion': False, 'use_flash_attention': False, 'num_layers': 6, 'hidden_size': 768, 'ffn_hidden_size': 2048, 'num_attention_heads': 12, 'init_method_std': 0.015, 'hidden_dropout': 0.1, 'attention_dropout': 0.1, 'kv_channels': 64, 'activation': 'geglu', 'masked_softmax_fusion': False}, 'decoder': {'arch': 'transformer', 'bias_activation_fusion': False, 'use_flash_attention': False, 'num_layers': 12, 'hidden_size': 768, 'ffn_hidden_size': 2048, 'num_attention_heads': 12, 'init_method_std': 0.015, 'hidden_dropout': 0.1, 'attention_dropout': 0.1, 'kv_channels': 64, 'activation': 'geglu', 'layer_type': [1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 1, 1], 'masked_softmax_fusion': False}, 'megatron_amp_O2': False, 'micro_batch_size': 1, 'global_batch_size': 1, 'precision': '32-true', 'seq_length': 512, 'max_position_embeddings': 512, 'use_flash_attention': False, 'target': 'nemo.collections.tts.models.speechllm.megatron_t5_speechllm_model.MegatronT5OverrideModel', 'nemo_version': '1.23.0rc0'}. Set this in model_parallel_config if using pipeline parallelism.
# [NeMo W 2024-10-25 06:48:36 modelPT:258] You tried to register an artifact under config key=tokenizer.vocab_file but an artifact for it has already been registered.
# [NeMo I 2024-10-25 06:48:36 tokenizer_utils:204] Getting Megatron tokenizer for pretrained model name: megatron-bert-345m-cased, custom vocab file: /Data/Checkpoints/9a77f10c2793465e8e8a3fa5fcbef8b0_vocab.txt, and merges file: None
# [NeMo I 2024-10-25 06:48:36 tokenizer_utils:130] Getting HuggingFace AutoTokenizer with pretrained_model_name: bert-large-cased, vocab_file: /Data/Checkpoints/9a77f10c2793465e8e8a3fa5fcbef8b0_vocab.txt, merges_files: None, special_tokens_dict: {}, and use_fast: False
# [NeMo I 2024-10-25 06:49:43 auto_tokenizer:173] 10128 special tokens added, resize your model accordingly.
# [NeMo I 2024-10-25 06:49:43 megatron_base_model:520] Padded vocab_size: 39168, original vocab_size: 39124, dummy tokens: 44.
# Number of parameters: 217198848
# [NeMo I 2024-10-25 06:49:43 megatron_t5_speechllm_model:535] self.frozen_model MegatronT5OverrideModel(
#       (enc_dec_model): MegatronTokenLevelEncoderDecoderSpeechLLMModule(
#         (encoder_embedding): Embedding(
#           (word_embeddings): VocabParallelEmbedding()
#           (position_embeddings): Embedding(512, 768)
#           (embedding_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (decoder_embedding): Embedding(
#           (word_embeddings): VocabParallelEmbedding()
#           (position_embeddings): Embedding(512, 768)
#           (embedding_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (enc_dec_model): MegatronTransformerEncoderDecoderModule(
#           (encoder): MultiMegatronTransformerEncoderModule(
#             (model): ModuleList(
#               (0-1): 2 x ParallelTransformer(
#                 (layers): ModuleList(
#                   (0-5): 6 x ParallelTransformerLayer(
#                     (input_layernorm): MixedFusedLayerNorm(torch.Size([768]), eps=1e-05, elementwise_affine=True)
#                     (self_attention): ParallelAttention(
#                       (query_key_value): ColumnParallelLinear()
#                       (core_attention): CoreAttention(
#                         (scale_mask_softmax): MatchedScaleMaskSoftmax()
#                         (attention_dropout): Dropout(p=0.1, inplace=False)
#                       )
#                       (dense): RowParallelLinear()
#                     )
#                     (post_attention_layernorm): MixedFusedLayerNorm(torch.Size([768]), eps=1e-05, elementwise_affine=True)
#                     (mlp): ParallelMLP(
#                       (dense_h_to_4h): ColumnParallelLinear()
#                       (dense_h_to_4h_2): ColumnParallelLinear()
#                       (dense_4h_to_h): RowParallelLinear()
#                     )
#                   )
#                 )
#                 (final_layernorm): MixedFusedLayerNorm(torch.Size([768]), eps=1e-05, elementwise_affine=True)
#               )
#             )
#           )
#           (decoder): MegatronTransformerDecoderModule(
#             (model): ParallelTransformer(
#               (layers): ModuleList(
#                 (0-2): 3 x ParallelTransformerLayer(
#                   (input_layernorm): MixedFusedLayerNorm(torch.Size([768]), eps=1e-05, elementwise_affine=True)
#                   (self_attention): ParallelAttention(
#                     (query_key_value): ColumnParallelLinear()
#                     (core_attention): CoreAttention(
#                       (scale_mask_softmax): MatchedScaleMaskSoftmax()
#                       (attention_dropout): Dropout(p=0.1, inplace=False)
#                     )
#                     (dense): RowParallelLinear()
#                   )
#                   (post_attention_layernorm): MixedFusedLayerNorm(torch.Size([768]), eps=1e-05, elementwise_affine=True)
#                   (mlp): ParallelMLP(
#                     (dense_h_to_4h): ColumnParallelLinear()
#                     (dense_h_to_4h_2): ColumnParallelLinear()
#                     (dense_4h_to_h): RowParallelLinear()
#                   )
#                 )
#                 (3-9): 7 x ParallelTransformerLayer(
#                   (input_layernorm): MixedFusedLayerNorm(torch.Size([768]), eps=1e-05, elementwise_affine=True)
#                   (self_attention): ParallelAttention(
#                     (query_key_value): ColumnParallelLinear()
#                     (core_attention): CoreAttention(
#                       (scale_mask_softmax): MatchedScaleMaskSoftmax()
#                       (attention_dropout): Dropout(p=0.1, inplace=False)
#                     )
#                     (dense): RowParallelLinear()
#                   )
#                   (post_attention_layernorm): MixedFusedLayerNorm(torch.Size([768]), eps=1e-05, elementwise_affine=True)
#                   (inter_attention): ParallelAttention(
#                     (query): ColumnParallelLinear()
#                     (key_value): ColumnParallelLinear()
#                     (core_attention): CoreAttention(
#                       (scale_mask_softmax): MatchedScaleMaskSoftmax()
#                       (attention_dropout): Dropout(p=0.1, inplace=False)
#                     )
#                     (dense): RowParallelLinear()
#                   )
#                   (post_inter_attention_layernorm): MixedFusedLayerNorm(torch.Size([768]), eps=1e-05, elementwise_affine=True)
#                   (mlp): ParallelMLP(
#                     (dense_h_to_4h): ColumnParallelLinear()
#                     (dense_h_to_4h_2): ColumnParallelLinear()
#                     (dense_4h_to_h): RowParallelLinear()
#                   )
#                 )
#                 (10-11): 2 x ParallelTransformerLayer(
#                   (input_layernorm): MixedFusedLayerNorm(torch.Size([768]), eps=1e-05, elementwise_affine=True)
#                   (self_attention): ParallelAttention(
#                     (query_key_value): ColumnParallelLinear()
#                     (core_attention): CoreAttention(
#                       (scale_mask_softmax): MatchedScaleMaskSoftmax()
#                       (attention_dropout): Dropout(p=0.1, inplace=False)
#                     )
#                     (dense): RowParallelLinear()
#                   )
#                   (post_attention_layernorm): MixedFusedLayerNorm(torch.Size([768]), eps=1e-05, elementwise_affine=True)
#                   (mlp): ParallelMLP(
#                     (dense_h_to_4h): ColumnParallelLinear()
#                     (dense_h_to_4h_2): ColumnParallelLinear()
#                     (dense_4h_to_h): RowParallelLinear()
#                   )
#                 )
#               )
#               (final_layernorm): MixedFusedLayerNorm(torch.Size([768]), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (tokens_head): MegatronTokenLevelHead()
#       )
#     )
# [NeMo I 2024-10-25 06:49:43 auto_tokenizer:173] 3 special tokens added, resize your model accordingly.
# [NeMo W 2024-10-25 06:49:44 modelPT:165] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       dataset_type: tarred_vocoder
#       dataset_args:
#         dataset_meta:
#           mls_english:
#             manifest_path: /lustre/fsw/portfolios/llmservice/projects/llmservice_nemo_speechlm/data/TTS/mls_english/filtered_22khz/tarred_audio/train_manifest.json
#             tar_filepath: /lustre/fsw/portfolios/llmservice/projects/llmservice_nemo_speechlm/data/TTS/mls_english/filtered_22khz/tarred_audio/audio_{0..1999}.tar
#           cv:
#             manifest_path: /lustre/fsw/portfolios/llmservice/projects/llmservice_nemo_speechlm/data/TTS/commonvoice13/22khz/tarred_audio/train_manifest.json
#             tar_filepath: /lustre/fsw/portfolios/llmservice/projects/llmservice_nemo_speechlm/data/TTS/commonvoice13/22khz/tarred_audio/audio_{0..279}.tar
#         sample_rate: 22050
#         n_samples: 24576
#         min_duration: 0.4
#         max_duration: null
#         shard_strategy: replicate
#         sample_type: weighted_random
#         sample_args:
#           batch_size: 32
#           steps_per_epoch: 1000
#           dataset_weights:
#           - 0.75
#           - 0.25
#         shuffle_n: 10000
#     dataloader_params:
#       batch_size: 32
#       drop_last: true
#       num_workers: 4
#
# [NeMo W 2024-10-25 06:49:44 modelPT:172] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       dataset_type: vocoder
#       dataset_args:
#         sample_rate: 22050
#         n_samples: null
#         min_duration: null
#         max_duration: null
#         trunc_duration: 10.0
#         dataset_meta:
#           mls_english:
#             manifest_path: /lustre/fsw/portfolios/llmservice/projects/llmservice_nemo_speechlm/data/TTS/mls_english/filtered_22khz/val_manifest_unseen.json
#             audio_dir: /lustre/fsw/portfolios/llmservice/projects/llmservice_nemo_speechlm/data/TTS/mls_english/filtered_22khz/audio_22khz
#           cv:
#             manifest_path: /lustre/fsw/portfolios/llmservice/projects/llmservice_nemo_speechlm/data/TTS/commonvoice13/22khz/val_manifest.json
#             audio_dir: /lustre/fsw/portfolios/llmservice/projects/llmservice_nemo_speechlm/data/TTS/commonvoice13/22khz/audio_22khz
#     dataloader_params:
#       batch_size: 4
#       num_workers: 2
#
# [NeMo W 2024-10-25 06:49:44 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#       warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# [NeMo I 2024-10-25 06:49:44 audio_codec:93] Vector quantizer does not support commit loss.
# [NeMo W 2024-10-25 06:49:45 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/torch/_utils.py:836: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#       return self.fget.__get__(instance, owner)()
#
# Some weights of the model checkpoint at microsoft/wavlm-base-plus were not used when initializing WavLMModel: ['encoder.pos_conv_embed.conv.weight_g', 'encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing WavLMModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing WavLMModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of WavLMModel were not initialized from the model checkpoint at microsoft/wavlm-base-plus and are newly initialized: ['encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [NeMo I 2024-10-25 06:49:45 features:289] PADDING: 1
# [NeMo I 2024-10-25 06:49:45 features:289] PADDING: 1
# [NeMo I 2024-10-25 06:49:45 features:289] PADDING: 1
# [NeMo I 2024-10-25 06:49:45 features:289] PADDING: 1
# [NeMo I 2024-10-25 06:49:45 features:289] PADDING: 1
# [NeMo I 2024-10-25 06:49:45 features:289] PADDING: 1
# [NeMo I 2024-10-25 06:49:45 features:289] PADDING: 1
# [NeMo I 2024-10-25 06:49:46 save_restore_connector:263] Model AudioCodecModel was successfully restored from /Data/Checkpoints/AudioCodec_21Hz_no_eliz.nemo.
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# [NeMo W 2024-10-25 06:49:47 experimental:26] `<class 'nemo.collections.tts.g2p.models.i18n_ipa.IpaG2p'>` is experimental and not ready for production yet. Use at your own risk.
# [NeMo W 2024-10-25 06:49:48 i18n_ipa:124] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2024-10-25 06:49:48 experimental:26] `<class 'nemo.collections.common.tokenizers.text_to_speech.tts_tokenizers.IPATokenizer'>` is experimental and not ready for production yet. Use at your own risk.
# [NeMo I 2024-10-25 06:49:48 base_prompt_learning_dataset:61] Loading and tokenizing dataset ...
# [NeMo I 2024-10-25 06:49:48 t5_speechllm_dataset:341] copy_dataset len === 1
#   0%|          | 0/1 [00:00<?, ?it/s]
# [NeMo I 2024-10-25 06:49:48 t5_speechllm_dataset:441] Skipped 0 sentences, sequence length too short or too long even after truncation
# [NeMo I 2024-10-25 06:49:48 megatron_t5_speechllm_model:1570] build success: 1 ['/Data/NotebookInference/dummy_val.json']
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [NeMo W 2024-10-25 06:49:48 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:438: PossibleUserWarning: The dataloader, test_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#       rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# [NeMo I 2024-10-25 06:49:49 megatron_t5_speechllm_model:1879] End detected for item 0 at timestep 32
# All ends detected
# [NeMo I 2024-10-25 06:49:49 cloud:58] Found existing object /root/.cache/torch/NeMo/NeMo_1.23.0rc0/titanet-l/11ba0924fdf87c049e339adbf6899d48/titanet-l.nemo.
# [NeMo I 2024-10-25 06:49:49 cloud:64] Re-using file from: /root/.cache/torch/NeMo/NeMo_1.23.0rc0/titanet-l/11ba0924fdf87c049e339adbf6899d48/titanet-l.nemo
# [NeMo I 2024-10-25 06:49:49 common:815] Instantiating model from pre-trained checkpoint
# [NeMo W 2024-10-25 06:49:49 modelPT:165] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/train.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 64
#     shuffle: true
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       noise:
#         manifest_path: /manifests/noise/rir_noise_manifest.json
#         prob: 0.5
#         min_snr_db: 0
#         max_snr_db: 15
#       speed:
#         prob: 0.5
#         sr: 16000
#         resample_type: kaiser_fast
#         min_speed_rate: 0.95
#         max_speed_rate: 1.05
#     num_workers: 15
#     pin_memory: true
#
# [NeMo W 2024-10-25 06:49:49 modelPT:172] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/dev.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 128
#     shuffle: false
#     num_workers: 15
#     pin_memory: true
# [NeMo I 2024-10-25 06:49:49 features:289] PADDING: 16
# [NeMo I 2024-10-25 06:49:50 save_restore_connector:263] Model EncDecSpeakerLabelModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.23.0rc0/titanet-l/11ba0924fdf87c049e339adbf6899d48/titanet-l.nemo.
# [NeMo I 2024-10-25 06:49:50 megatron_t5_speechllm_model:1983] Loaded SV Model: EncDecSpeakerLabelModel(
#       (loss): AngularSoftmaxLoss()
#       (eval_loss): AngularSoftmaxLoss()
#       (_accuracy): TopKClassificationAccuracy()
#       (preprocessor): AudioToMelSpectrogramPreprocessor(
#         (featurizer): FilterbankFeatures()
#       )
#       (encoder): ConvASREncoder(
#         (encoder): Sequential(
#           (0): JasperBlock(
#             (mconv): ModuleList(
#               (0): MaskedConv1d(
#                 (conv): Conv1d(80, 80, kernel_size=(3,), stride=(1,), padding=(1,), groups=80, bias=False)
#               )
#               (1): MaskedConv1d(
#                 (conv): Conv1d(80, 1024, kernel_size=(1,), stride=(1,), bias=False)
#               )
#               (2): BatchNorm1d(1024, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): SqueezeExcite(
#                 (fc): Sequential(
#                   (0): Linear(in_features=1024, out_features=128, bias=False)
#                   (1): ReLU(inplace=True)
#                   (2): Linear(in_features=128, out_features=1024, bias=False)
#                 )
#                 (gap): AdaptiveAvgPool1d(output_size=1)
#               )
#             )
#             (mout): Sequential(
#               (0): ReLU(inplace=True)
#               (1): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (1): JasperBlock(
#             (mconv): ModuleList(
#               (0): MaskedConv1d(
#                 (conv): Conv1d(1024, 1024, kernel_size=(7,), stride=(1,), padding=(3,), groups=1024, bias=False)
#               )
#               (1): MaskedConv1d(
#                 (conv): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,), bias=False)
#               )
#               (2): BatchNorm1d(1024, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ReLU(inplace=True)
#               (4): Dropout(p=0.1, inplace=False)
#               (5): MaskedConv1d(
#                 (conv): Conv1d(1024, 1024, kernel_size=(7,), stride=(1,), padding=(3,), groups=1024, bias=False)
#               )
# ...
#                 (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (output_dropout): Dropout(p=0.1, inplace=False)
#               )
#               (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#       (projector): Linear(in_features=768, out_features=512, bias=True)
#       (tdnn): ModuleList(
#         (0): TDNNLayer(
#           (kernel): Linear(in_features=2560, out_features=512, bias=True)
#           (activation): ReLU()
#         )
#         (1-2): 2 x TDNNLayer(
#           (kernel): Linear(in_features=1536, out_features=512, bias=True)
#           (activation): ReLU()
#         )
#         (3): TDNNLayer(
#           (kernel): Linear(in_features=512, out_features=512, bias=True)
#           (activation): ReLU()
#         )
#         (4): TDNNLayer(
#           (kernel): Linear(in_features=512, out_features=1500, bias=True)
#           (activation): ReLU()
#         )
#       )
#       (feature_extractor): Linear(in_features=3000, out_features=512, bias=True)
#       (classifier): Linear(in_features=512, out_features=512, bias=True)
#       (objective): AMSoftmaxLoss(
#         (loss): CrossEntropyLoss()
#       )
#     )
# [NeMo I 2024-10-25 06:49:54 megatron_t5_speechllm_model:2110] Clipping until end index for audio 0
# It is strongly recommended to pass the ``sampling_rate`` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
# [NeMo W 2024-10-25 06:49:55 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5083: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#       warnings.warn(
#
# It is strongly recommended to pass the ``sampling_rate`` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#
# Transcribing:   0%|                                                                                       | 0/1 [00:00<?, ?it/s]
# Transcribing: 100%|███████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.04it/s]
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test titanet_avg_cossim: -0.14843271672725677
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test titanet_avg_cossim_context_pred: -0.14843271672725677
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test titanet_avg_cossim_context_gt: 1.0000001192092896
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test wavlm_avg_cossim: 0.6568089723587036
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test wavlm_avg_cossim_context_pred: 0.6568881273269653
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test wavlm_avg_cossim_context_gt: 1.0
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test squim_mos_pred_GT: 3.940303325653076
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test squim_mos_GT_context: 3.9421274662017822
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test squim_mos_pred_context: 3.929391384124756
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test cer_transcript: inf
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test wer_transcript: inf
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test cer_phoneme: inf
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test wer_phoneme: inf
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#       return _methods._mean(a, axis=axis, dtype=dtype,
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#       ret = ret.dtype.type(ret / rcount)
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test cer_tts: nan
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test wer_tts: nan
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test cer_transcript_gt: 0.0
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test wer_transcript_gt: 0.0
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test cer_phoneme_gt: 0.0
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test wer_phoneme_gt: 0.0
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test cer_tts_gt: nan
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test wer_tts_gt: nan
# [NeMo I 2024-10-25 06:49:56 megatron_t5_speechllm_model:1478] Test RTF: 1.0382100755739356
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_titanet_avg_cossim', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_titanet_avg_cossim_context_pred', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_titanet_avg_cossim_context_gt', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_wavlm_avg_cossim', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_wavlm_avg_cossim_context_pred', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_wavlm_avg_cossim_context_gt', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_squim_mos_pred_GT', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_squim_mos_GT_context', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_squim_mos_pred_context', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_cer_transcript', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_wer_transcript', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_cer_phoneme', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_wer_phoneme', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_cer_tts', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_wer_tts', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_cer_transcript_gt', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_wer_transcript_gt', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_cer_phoneme_gt', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_wer_phoneme_gt', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_cer_tts_gt', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_wer_tts_gt', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2024-10-25 06:49:56 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:433: PossibleUserWarning: It is recommended to use `self.log('test_RTF', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Test metric              ┃             DataLoader 0             ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │               test_RTF               │          1.0382100343704224          │
# │           test_cer_phoneme           │                 inf                  │
# │         test_cer_phoneme_gt          │                 0.0                  │
# │         test_cer_transcript          │                 inf                  │
# │        test_cer_transcript_gt        │                 0.0                  │
# │             test_cer_tts             │                 nan                  │
# │           test_cer_tts_gt            │                 nan                  │
# │      test_squim_mos_GT_context       │          3.9421274662017822          │
# │        test_squim_mos_pred_GT        │          3.940303325653076           │
# │     test_squim_mos_pred_context      │          3.929391384124756           │
# │       test_titanet_avg_cossim        │         -0.14843271672725677         │
# │  test_titanet_avg_cossim_context_gt  │          1.0000001192092896          │
# │ test_titanet_avg_cossim_context_pred │         -0.14843271672725677         │
# │        test_wavlm_avg_cossim         │          0.6568089723587036          │
# │   test_wavlm_avg_cossim_context_gt   │                 1.0                  │
# │  test_wavlm_avg_cossim_context_pred  │          0.6568881273269653          │
# │           test_wer_phoneme           │                 inf                  │
# │         test_wer_phoneme_gt          │                 0.0                  │
# │         test_wer_transcript          │                 inf                  │
# │        test_wer_transcript_gt        │                 0.0                  │
# │             test_wer_tts             │                 nan                  │
# │           test_wer_tts_gt            │                 nan                  │
# └──────────────────────────────────────┴──────────────────────────────────────┘
# [{'test_titanet_avg_cossim': -0.14843271672725677,
#   'test_titanet_avg_cossim_context_pred': -0.14843271672725677,
#   'test_titanet_avg_cossim_context_gt': 1.0000001192092896,
#   'test_wavlm_avg_cossim': 0.6568089723587036,
#   'test_wavlm_avg_cossim_context_pred': 0.6568881273269653,
#   'test_wavlm_avg_cossim_context_gt': 1.0,
#   'test_squim_mos_pred_GT': 3.940303325653076,
#   'test_squim_mos_GT_context': 3.9421274662017822,
#   'test_squim_mos_pred_context': 3.929391384124756,
#   'test_cer_transcript': inf,
#   'test_wer_transcript': inf,
#   'test_cer_phoneme': inf,
#   'test_wer_phoneme': inf,
#   'test_cer_tts': nan,
#   'test_wer_tts': nan,
#   'test_cer_transcript_gt': 0.0,
#   'test_wer_transcript_gt': 0.0,
#   'test_cer_phoneme_gt': 0.0,
#   'test_wer_phoneme_gt': 0.0,
#   'test_cer_tts_gt': nan,
#   'test_wer_tts_gt': nan,
#   'test_RTF': 1.0382100343704224}]

# %% [markdown]
# ## Helper functions

# %%
out_dir = os.path.join( model.trainer.logger.save_dir, model.trainer.logger.name, model.trainer.logger.version, "Sample_Audios")
out_path = os.path.join(out_dir, 'predicted_wav_0.wav')


def encode(wav_path):
    # Convert an audio file to nemo codec codes
    features = AudioSegment.segment_from_file(
                    wav_path, target_sr=codec_model.sample_rate, n_segments=-1, trim=False,
                )
    audio_samples = features.samples
    audio = torch.tensor(audio_samples).cuda()
    audio_length = torch.tensor(audio.size(0)).long().cuda()
    print(f"audio {audio.size()} audio_length {audio_length}")
    print(f"audio {audio.device} audio_length {audio_length.device} codec_model {codec_model.device}")

    original_codec_codes, _ = codec_model.encode(audio=audio.unsqueeze(0), audio_len=audio_length.unsqueeze(0))
    original_codec_codes = original_codec_codes[0]
    print(f"original_codec_codes {original_codec_codes.size()} audio {audio.size()} audio_length {audio_length}")
    duration = original_codec_codes.size()[1] / 86
    
    target_codec_filepath = wav_path[:-4] + "_codes.pt"
    torch.save(original_codec_codes.cpu().type(torch.int16), target_codec_filepath)
    return original_codec_codes, target_codec_filepath, duration
    
    
    
def play_codec(codec_path):
    # Convert nemo codecs to audio and play it
    codec = torch.load(codec_path)
    codec = codec.to('cuda')
    codec = codec.unsqueeze(0)
    codec_lens = torch.Tensor([codec.shape[2]]).long().cuda()
    codec_decoded_audios, _ = codec_model.decode(tokens=codec.long(), tokens_len=codec_lens)
    codec_decoded_audio = codec_decoded_audios[0]
    temp_wav_path = os.path.join(EXP_DIR, "temp.wav")
    torchaudio.save(temp_wav_path, codec_decoded_audio[None].cpu(), 22050)
    display(Audio(temp_wav_path))

def generate_new_audio(
    text,
    context,
    context_duration=4.0,
    context_type="REFSPEAKERCODEC",
    temperature=0.85,
    top_k=80,
    text_task="Phoneme TTS "
    ):
    # Prepare data in speechllm format
    model.cfg.temperature = temperature
    model.cfg.top_k = top_k
    dummy_answer = dummy_codes_fp
    json_in = {}
    json_in["question"] = text_task + text
    json_in["question_type"] = "TEXT"
    json_in["answer"] = dummy_answer 
    json_in["context"] = context 
    json_in["answer_type"] = "AUDIOCODEC"
    json_in["context_type"] = context_type
    json_in["context_duration"] = context_duration
    json_in["answer_duration"] = 2.0
    json_in["taskname"] = "squad"
    json_in["lang"] = "en"
    json_in = [json_in]
    
    # Prepare dataloader
    model._test_ds.examples = []
    model._test_ds.examples = model._test_ds.load_data(json_in)
    
    sampler = torch.utils.data.distributed.DistributedSampler(
            model._test_ds, num_replicas=1, rank=0, shuffle=False, seed=1
        )

    model._test_dl = torch.utils.data.DataLoader(
        model._test_ds,
        collate_fn=model._test_ds.collate_fn,
        sampler=sampler,
        batch_size=1,
        drop_last=False,
        num_workers=1,
        pin_memory=False,
        persistent_workers=True
    )
    
    # Run inference
    model.cfg.data.test_ds = None
    trainer.test(model, model._test_dl)
    print("Out path:", out_path)
    print("Inference done")

# %%
text_contexts = [
    "TEXT CONTEXT: | Language:en Dataset:Riva Speaker:Lindy_WIZWIKI |",
    "TEXT CONTEXT: | Language:en Dataset:Riva Speaker:Lindy_CMU_FEARFUL |",
    "TEXT CONTEXT: | Language:en Dataset:Riva Speaker:Lindy_CMU_HAPPY |",
    "TEXT CONTEXT: | Language:en Dataset:Riva Speaker:Rodney_CMU_HAPPY |",
    "TEXT CONTEXT: | Language:en  Dataset:PromptTTS Gender:female SpeakingRate:2. Slow emotion:neutral Pitch:4. High SNR:5. Clean REVERB:5. Very close-sounding |"
]

# %% [markdown]
# ## Generate audio from a text context

# %%
text = "We present audio examples for our paper Improving Robustness of L L M based Speech Synthesis by Learning Monotonic Alignment."
# text = "As I closed my laptop for the night, my reflection in the screen continued to smile back at me."
text_task = "Phoneme TTS " # Can be "Text to speech this " (for sentence-piece tokenizer) or "Phoneme TTS " (for phoneme tokenizer)
context = text_contexts[0] # Sample Text Context
context_type = "TEXT" # Can be REFSPEAKERCODEC (for audio context), TEXT (for text context)
generate_new_audio(
    text, 
    context, 
    context_type=context_type, 
    context_duration=5.0, # Does not matter, should just be > 3 so that dataset does not filter it out.
    top_k=160, # Can play around with this to check roubstness
    temperature=0.85, # Can play around with this. temperature < 0.85 can be more robust
    text_task=text_task
)
display(Audio(out_path))
# Out:
# [NeMo I 2024-10-25 06:50:18 t5_speechllm_dataset:341] copy_dataset len === 1
#   0%|          | 0/1 [00:00<?, ?it/s]
# [NeMo I 2024-10-25 06:50:18 t5_speechllm_dataset:441] Skipped 0 sentences, sequence length too short or too long even after truncation
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [NeMo W 2024-10-25 06:50:18 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:438: PossibleUserWarning: The dataloader, test_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#       rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# [NeMo I 2024-10-25 06:50:21 megatron_t5_speechllm_model:1745] Timestep 100
# [NeMo I 2024-10-25 06:50:22 megatron_t5_speechllm_model:1879] End detected for item 0 at timestep 159
# All ends detected
# [NeMo I 2024-10-25 06:50:22 megatron_t5_speechllm_model:2110] Clipping until end index for audio 0
# It is strongly recommended to pass the ``sampling_rate`` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
# [NeMo W 2024-10-25 06:50:23 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5083: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#       warnings.warn(
#
#
# Transcribing:   0%|                                                                                       | 0/1 [00:00<?, ?it/s]
# Transcribing: 100%|███████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.52it/s]
# [NeMo W 2024-10-25 06:50:23 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#       return _methods._mean(a, axis=axis, dtype=dtype,
#
# [NeMo W 2024-10-25 06:50:23 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#       ret = ret.dtype.type(ret / rcount)
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test titanet_avg_cossim: -0.05183608829975128
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test titanet_avg_cossim_context_pred: nan
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test titanet_avg_cossim_context_gt: nan
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test wavlm_avg_cossim: 0.6416186690330505
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test wavlm_avg_cossim_context_pred: nan
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test wavlm_avg_cossim_context_gt: nan
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test squim_mos_pred_GT: 2.657832463582357
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test squim_mos_GT_context: nan
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test squim_mos_pred_context: nan
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test cer_transcript: inf
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test wer_transcript: inf
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test cer_phoneme: inf
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test wer_phoneme: inf
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test cer_tts: nan
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test wer_tts: nan
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test cer_transcript_gt: 0.026881720430107527
# [NeMo I 2024-10-25 06:50:23 megatron_t5_speechllm_model:1478] Test wer_transcript_gt: 0.08333333333333333
# [NeMo I 2024-10-25 06:50:24 megatron_t5_speechllm_model:1478] Test cer_phoneme_gt: 0.026881720430107527
# [NeMo I 2024-10-25 06:50:24 megatron_t5_speechllm_model:1478] Test wer_phoneme_gt: 0.08333333333333333
# [NeMo I 2024-10-25 06:50:24 megatron_t5_speechllm_model:1478] Test cer_tts_gt: nan
# [NeMo I 2024-10-25 06:50:24 megatron_t5_speechllm_model:1478] Test wer_tts_gt: nan
# [NeMo I 2024-10-25 06:50:24 megatron_t5_speechllm_model:1478] Test RTF: 0.6866240966662901
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Test metric              ┃             DataLoader 0             ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │               test_RTF               │          0.6866241097450256          │
# │           test_cer_phoneme           │                 inf                  │
# │         test_cer_phoneme_gt          │         0.02688172087073326          │
# │         test_cer_transcript          │                 inf                  │
# │        test_cer_transcript_gt        │         0.02688172087073326          │
# │             test_cer_tts             │                 nan                  │
# │           test_cer_tts_gt            │                 nan                  │
# │      test_squim_mos_GT_context       │                 nan                  │
# │        test_squim_mos_pred_GT        │          2.657832384109497           │
# │     test_squim_mos_pred_context      │                 nan                  │
# │       test_titanet_avg_cossim        │         -0.05183608829975128         │
# │  test_titanet_avg_cossim_context_gt  │                 nan                  │
# │ test_titanet_avg_cossim_context_pred │                 nan                  │
# │        test_wavlm_avg_cossim         │          0.6416186690330505          │
# │   test_wavlm_avg_cossim_context_gt   │                 nan                  │
# │  test_wavlm_avg_cossim_context_pred  │                 nan                  │
# │           test_wer_phoneme           │                 inf                  │
# │         test_wer_phoneme_gt          │          0.0833333358168602          │
# │         test_wer_transcript          │                 inf                  │
# │        test_wer_transcript_gt        │          0.0833333358168602          │
# │             test_wer_tts             │                 nan                  │
# │           test_wer_tts_gt            │                 nan                  │
# └──────────────────────────────────────┴──────────────────────────────────────┘
# Out path: /home/shehzeenh/Code/NeMo/nemo_experiments/megatron_t5_speechllm/Sample_Audios/predicted_wav_0.wav
# Inference done
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Listen to some ground-truth context audios

# %%
context_paths = [
    "/datap/misc/speechllm_codecdatasets/codecs/RivattsAllLanguagesUpdated_train_nemo_codec_bw_6.0/target_codes_en_Lindy_44khz_CMU_HAPPY_LINDY_CMU_HAPPY_000570.pt",
]

for cidx, context_path in enumerate(context_paths):
    print(cidx, context_path)
    play_codec(context_path)

# %% [markdown]
# ## Generate audio from an audio context

# %%
text = "As I closed my laptop for the night, my reflection in the screen continued to smile back at me."
text_task = "Text to speech this " # Can be "Text to speech this " (for sentence-piece tokenizer) or "Phoneme TTS " (for phoneme tokenizer)
context = context_paths[0] # Sample Text Context
context_type = "REFSPEAKERCODEC" # Can be REFSPEAKERCODEC (for audio context), TEXT (for text context)
generate_new_audio(
    text, 
    context, 
    context_type=context_type, 
    context_duration=5.0, # Does not matter, should just be > 3 so that dataset does not filter it out.
    temperature=0.8, # Can play around with this. temperature < 0.85 can be more robust
    text_task=text_task
)
display(Audio(out_path))
